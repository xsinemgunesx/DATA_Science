# %%
#LİSTELER
benimlistem = []
benimlistem
# Out:
# []

# %%
list("89033")
# Out:
# ['8', '9', '0', '3', '3']

# %%
a = list("939493483473")
a
# Out:
# ['9', '3', '9', '4', '9', '3', '4', '8', '3', '4', '7', '3']

# %%
list(range(1,500,15))
# Out:
# [1,
#  16,
#  31,
#  46,
#  61,
#  76,
#  91,
#  106,
#  121,
#  136,
#  151,
#  166,
#  181,
#  196,
#  211,
#  226,
#  241,
#  256,
#  271,
#  286,
#  301,
#  316,
#  331,
#  346,
#  361,
#  376,
#  391,
#  406,
#  421,
#  436,
#  451,
#  466,
#  481,
#  496]

# %%
def min_list(list):
  min = list[0]
  for i in list :
    if i < min:
      min = i
      return min
print(min_list([800,1,76,43,23,78]))
# Out:
# 1

# %%
import pandas as pd

# %%
sayilar = [100,101,102,103]

# %%
pd.Series(sayilar)
# Out:
# 0    100
# 1    101
# 2    102
# 3    103
# dtype: int64

# %%
harfler = ['a','b','c','a']

# %%
pd.Series(sayilar,harfler)
# Out:
# a    100
# b    101
# c    102
# a    103
# dtype: int64

# %%
dictionary = {"name" :"Hakan","age": 30,"occupation" : "engineer"}

# %%
a = pd.Series(dictionary)

# %%
a.index
# Out:
# Index(['name', 'age', 'occupation'], dtype='object')

# %%
a.size
# Out:
# 3

# %%
type(a)
# Out:
# pandas.core.series.Series

# %% [markdown]
# sayilar = [100,101,102,103]

# %%
##NUMPY

# %%
import numpy as np

# %%
b = np.array([1,15,43,98])

# %%
type(b)
# Out:
# numpy.ndarray

# %%
c =np.random.randint(20,100,size=25)#random sayı üretme

# %%
# c.reshape(5,5 )
# Out:
# array([[56, 63, 37, 22, 80],
#        [61, 77, 30, 34, 48],
#        [45, 41, 41, 65, 98],
#        [46, 80, 41, 37, 33],
#        [28, 96, 62, 58, 83]])

# %%
z = np.random.randint(36,size = (6,6))

# %%
z
# Out:
# array([[ 1,  5,  8, 29, 20,  7],
#        [ 5,  3, 27,  0, 35,  0],
#        [ 2, 33, 22, 32, 22,  3],
#        [17, 17, 16, 30, 13,  1],
#        [32, 21, 13, 16, 18, 15],
#        [34, 27, 32, 11, 10, 24]])

# %%
z[4,5]
# Out:
# 15

# %%
z<=20
# Out:
# array([[ True,  True,  True, False,  True,  True],
#        [ True,  True, False,  True, False,  True],
#        [ True, False, False, False, False,  True],
#        [ True,  True,  True, False,  True,  True],
#        [False, False,  True,  True,  True,  True],
#        [False, False, False,  True,  True, False]])

# %%
z[z<10]
# Out:
# array([1, 5, 8, 7, 5, 3, 0, 0, 2, 3, 1])

# %%
z/100
# Out:
# array([[0.01, 0.05, 0.08, 0.29, 0.2 , 0.07],
#        [0.05, 0.03, 0.27, 0.  , 0.35, 0.  ],
#        [0.02, 0.33, 0.22, 0.32, 0.22, 0.03],
#        [0.17, 0.17, 0.16, 0.3 , 0.13, 0.01],
#        [0.32, 0.21, 0.13, 0.16, 0.18, 0.15],
#        [0.34, 0.27, 0.32, 0.11, 0.1 , 0.24]])

# %%
import seaborn as sns
import pandas as  pd
import matplotlib.pyplot as plt
plot = sns.load_dataset("exercise")# isimli dataset yükleme
plot.head()# ilk 5 satır
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
seaborn = sns.catplot(x = "time", y ="pulse", data = plot)
plt.show()

# %%
plot.shape #satır-sütün
# Out:
# (90, 6)

# %%
plot.info()#dataset hakkında bilgi
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  90 non-null     int64
#  1   id          90 non-null     int64
#  2   diet        90 non-null     category
#  3   pulse       90 non-null     int64
#  4   time        90 non-null     category
#  5   kind        90 non-null     category
# dtypes: category(3), int64(3)
# memory usage: 2.9 KB

# %%
plot.columns
# Out:
# Index(['Unnamed: 0', 'id', 'diet', 'pulse', 'time', 'kind'], dtype='object')

# %%
plot.describe()#istatistik değerler için
# Out:
#        Unnamed: 0         id       pulse
# count   90.000000  90.000000   90.000000
# mean    44.500000  15.500000   99.700000
# std     26.124701   8.703932   14.858471
# min      0.000000   1.000000   80.000000
# 25%     22.250000   8.000000   90.250000
# 50%     44.500000  15.500000   96.000000
# 75%     66.750000  23.000000  103.000000
# max     89.000000  30.000000  150.000000

# %%
plot["diet"].head(13)
# Out:
# 0     low fat
# 1     low fat
# 2     low fat
# 3     low fat
# 4     low fat
# 5     low fat
# 6     low fat
# 7     low fat
# 8     low fat
# 9     low fat
# 10    low fat
# 11    low fat
# 12    low fat
# Name: diet, dtype: category
# Categories (2, object): ['no fat', 'low fat']

# %%
type("diet")
# Out:
# str

# %%
 plot.drop(3,axis = 0).head(20) #3 index ve satır silinsin
# Out:
#     Unnamed: 0  id     diet  pulse    time  kind
# 0            0   1  low fat     85   1 min  rest
# 1            1   1  low fat     85  15 min  rest
# 2            2   1  low fat     88  30 min  rest
# 4            4   2  low fat     92  15 min  rest
# 5            5   2  low fat     93  30 min  rest
# 6            6   3  low fat     97   1 min  rest
# 7            7   3  low fat     97  15 min  rest
# 8            8   3  low fat     94  30 min  rest
# 9            9   4  low fat     80   1 min  rest
# 10          10   4  low fat     82  15 min  rest
# 11          11   4  low fat     83  30 min  rest
# 12          12   5  low fat     91   1 min  rest
# 13          13   5  low fat     92  15 min  rest
# 14          14   5  low fat     91  30 min  rest
# 15          15   6   no fat     83   1 min  rest
# 16          16   6   no fat     83  15 min  rest
# 17          17   6   no fat     84  30 min  rest
# 18          18   7   no fat     87   1 min  rest
# ...

# %%
plot["diet"].head()
type(plot["diet"].head())# 1.SERİES
# Out:
# pandas.core.series.Series

# %%
plot[["diet"]].head()
type(plot[["diet"]].head()) #2.DATAfRAME
# Out:
# pandas.core.frame.DataFrame

# %%
plot.loc[:,plot.columns.str.contains("diet")].head()#sadece diet içeren sütün
# Out:
#       diet
# 0  low fat
# 1  low fat
# 2  low fat
# 3  low fat
# 4  low fat

# %%
plot.loc[:,~plot.columns.str.contains("diet")].head()#diet dışındaki sütün => ~
# Out:
#    Unnamed: 0  id  pulse    time  kind
# 0           0   1     85   1 min  rest
# 1           1   1     85  15 min  rest
# 2           2   1     88  30 min  rest
# 3           3   2     90   1 min  rest
# 4           4   2     92  15 min  rest

# %%
plot.iloc[0:4] #index e göre sırala
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest

# %%
plot.loc[0:4] #içeriğe göre sıralama index e göre değil
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
#KOŞULLU SEÇİM İŞLEMİ

# %%
plot[plot["pulse"]>100].head()
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 34          34  12  low fat    103  15 min  walking
# 35          35  12  low fat    104  30 min  walking
# 48          48  17   no fat    103   1 min  walking
# 49          49  17   no fat    109  15 min  walking
# 53          53  18   no fat    101  30 min  walking

# %%
plot.loc[plot["pulse"]>100,["kind","time","pulse","diet"]]
# Out:
#        kind    time  pulse     diet
# 34  walking  15 min    103  low fat
# 35  walking  30 min    104  low fat
# 48  walking   1 min    103   no fat
# 49  walking  15 min    109   no fat
# 53  walking  30 min    101   no fat
# 57  walking   1 min    102   no fat
# 58  walking  15 min    104   no fat
# 59  walking  30 min    103   no fat
# 62  running  30 min    110  low fat
# 64  running  15 min    104  low fat
# 65  running  30 min    112  low fat
# 67  running  15 min    105  low fat
# 70  running  15 min    132  low fat
# 71  running  30 min    120  low fat
# 73  running  15 min    110  low fat
# 74  running  30 min    116  low fat
# 76  running  15 min    126   no fat
# 77  running  30 min    143   no fat
# 79  running  15 min    126   no fat
# 80  running  30 min    140   no fat
# 81  running   1 min    103   no fat
# 82  running  15 min    124   no fat
# 83  running  30 min    140   no fat
# 85  running  15 min    135   no fat
# 86  running  30 min    130   no fat
# ...

# %%
plot[plot["pulse"]>100].count()
# Out:
# Unnamed: 0    27
# id            27
# diet          27
# pulse         27
# time          27
# kind          27
# dtype: int64

# %%
plot["pulse"].mean()
# Out:
# 99.7

# %%
plot.groupby("kind")["pulse"].mean()
# Out:
# kind
# rest        90.833333
# walking     95.200000
# running    113.066667
# Name: pulse, dtype: float64

# %%
plot.pivot_table("pulse","kind","time")#pulse orta değer,kind satır, time sütun
# Out:
# time     1 min  15 min  30 min
# kind
# rest      90.2    90.9    91.4
# walking   93.1    96.6    95.9
# running   96.1   117.1   126.0

# %%
plot.pivot_table("pulse","kind","time", aggfunc="std")#standart sapma
# Out:
# time        1 min     15 min     30 min
# kind
# rest     6.545567   6.118279   5.337498
# walking  6.297266   7.441625   6.740425
# running  4.483302  12.991023  16.964014

# %% [markdown]
# # **VERİLERİ GÖRSELLEŞTİRME**
# 1-kategori? sayısal değişken ?

# %% [markdown]
# 1.Kategorik değişken
#   - value_counts

# %%
a = np.array([1,1000])

# %%
seri = pd.Series(['kırmızı','kırmızı','kırmızı','kırmızı','mavi','mavi','mavi','yeşil'])
sayilar = seri.value_counts()
print(sayilar)
# Out:
# kırmızı    4
# mavi       3
# yeşil      1
# dtype: int64
