# %%
import pandas as pd

# %%
df = pd.read_csv("HepatitisCdata.csv")

# %%
df
# Out:
#      Unnamed: 0       Category  Age Sex   ALB    ALP    ALT    AST   BIL  \
# 0             1  0=Blood Donor   32   m  38.5   52.5    7.7   22.1   7.5
# 1             2  0=Blood Donor   32   m  38.5   70.3   18.0   24.7   3.9
# 2             3  0=Blood Donor   32   m  46.9   74.7   36.2   52.6   6.1
# 3             4  0=Blood Donor   32   m  43.2   52.0   30.6   22.6  18.9
# 4             5  0=Blood Donor   32   m  39.2   74.1   32.6   24.8   9.6
# ..          ...            ...  ...  ..   ...    ...    ...    ...   ...
# 610         611    3=Cirrhosis   62   f  32.0  416.6    5.9  110.3  50.0
# 611         612    3=Cirrhosis   64   f  24.0  102.8    2.9   44.4  20.0
# 612         613    3=Cirrhosis   64   f  29.0   87.3    3.5   99.0  48.0
# 613         614    3=Cirrhosis   46   f  33.0    NaN   39.0   62.0  20.0
# 614         615    3=Cirrhosis   59   f  36.0    NaN  100.0   80.0  12.0
#
#        CHE  CHOL   CREA    GGT  PROT
# 0     6.93  3.23  106.0   12.1  69.0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Category', 'Age', 'Sex', 'ALB', 'ALP', 'ALT', 'AST',
#        'BIL', 'CHE', 'CHOL', 'CREA', 'GGT', 'PROT'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Category       object
# Age             int64
# Sex            object
# ALB           float64
# ALP           float64
# ALT           float64
# AST           float64
# BIL           float64
# CHE           float64
# CHOL          float64
# CREA          float64
# GGT           float64
# PROT          float64
# dtype: object

# %%
df.shape
# Out:
# (615, 14)

# %%
#sütunları seçme
df = df.loc[:,["Category","Sex","CHOL","GGT"]]
df.head()
# Out:
#         Category Sex  CHOL   GGT
# 0  0=Blood Donor   m  3.23  12.1
# 1  0=Blood Donor   m  4.80  15.6
# 2  0=Blood Donor   m  5.20  33.2
# 3  0=Blood Donor   m  4.74  33.8
# 4  0=Blood Donor   m  4.32  29.9

# %%
df.dtypes
# Out:
# Category     object
# Sex          object
# CHOL        float64
# GGT         float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Category     0
# Sex          0
# CHOL        10
# GGT          0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#           Category Sex  CHOL    GGT
# 0    0=Blood Donor   m  3.23   12.1
# 1    0=Blood Donor   m  4.80   15.6
# 2    0=Blood Donor   m  5.20   33.2
# 3    0=Blood Donor   m  4.74   33.8
# 4    0=Blood Donor   m  4.32   29.9
# ..             ...  ..   ...    ...
# 610    3=Cirrhosis   f  6.30  650.9
# 611    3=Cirrhosis   f  3.02   35.9
# 612    3=Cirrhosis   f  3.63   64.2
# 613    3=Cirrhosis   f  4.20   50.0
# 614    3=Cirrhosis   f  5.30   34.0
#
# [605 rows x 4 columns]

# %%
df.shape
# Out:
# (605, 4)

# %%
df["Sex"].value_counts()
# Out:
# m    374
# f    231
# Name: Sex, dtype: int64

# %%
#kadın-erkek sayısını eşitlemek için
df["Sex"].value_counts(normalize = True)
# Out:
# m    0.618182
# f    0.381818
# Name: Sex, dtype: float64

# %%
df[df["Age"] == "32"].Sex.value_counts(normalize = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
